# %%
import matplotlib  # 导入图表模块
import matplotlib.pyplot as plt  # 导入绘图模块

        
matplotlib.rcParams['font.family'] = 'Times New Roman'
matplotlib.rcParams['axes.unicode_minus'] = False

# %matplotlib inline
import os
os.environ["OMP_NUM_THREADS"]="7"
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

# %%
#导入数据
data=pd.read_csv(r".\result.csv",encoding="utf-8")
data.head()
# Out:
#            x          y
# 0  3425.5194  1250.3400
# 1  3958.6314   610.0560
# 2  3884.2980   311.4858
# 3  3855.5814   334.2942
# 4  3873.0312   330.8592

# %%
x=np.array(data["x"])
y=np.array(data["y"])
alpha = np.linspace(0,1, len(x))
for i in range(len(x)):
    plt.plot(x[:i], y[:i], color="blue",alpha=alpha[i])
plt.xlabel("x/nm")
plt.ylabel("y/nm")
plt.show()
