# %% [markdown]
# 决策树模型
#
# 1、遍历决策树所需的算力：O(log2(m))

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier

# %%
iris=datasets.load_iris()
x=iris["data"][:,2:]
y=iris["target"]
tree_clf=DecisionTreeClassifier()
tree_clf.fit(x,y)
print(tree_clf.predict([[5,1.5]]))
tree_clf.predict_proba([[5,1.5]])
# Out:
# [2]
# array([[0., 0., 1.]])

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree_clf,
                out_file="D:\机器学习/iris_tree.dot",
                feature_names=iris.feature_names[2:],
                class_names=iris.target_names,
                rounded=True,
                filled=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 from sklearn.tree import export_graphviz
# ----> 2 export_graphviz(tree_clf,
#       3                 out_file="D:\机器学习/iris_tree.dot",
#       4                 feature_names=iris.feature_names[2:],
#       5                 class_names=iris.target_names,
#       6                 rounded=True,
#       7                 filled=True)
#
# File c:\Users\youyiting\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...

# %%
import numpy as np
from sklearn.datasets import make_regression
X, y = make_regression(
    n_samples=100,      # 样本数量
    n_features=1,      # 特征数量，这里是1维数据
    n_informative=1,    # 有用的特征数量
    n_targets=1,       # 目标变量数量
    noise=0.1,         # 噪声水平
    bias=0.0,          # 偏差
    effective_rank=None,  # 特征矩阵的有效秩
    tail_strength=0.5, # 尾部强度
    random_state=42    # 随机数生成器的种子
)

# 将数据集转换为二次数据集
X2 = X ** 2  # X的平方
y2 = y + np.random.normal(0, 0.1, y.shape)  # y加上噪声
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2)
